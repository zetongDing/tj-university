# %%
import os
import torch
import torch.nn as nn
from torch.autograd import Variable
import torch.utils.data as Data
import torchvision
import torch.nn.functional as F
import numpy as np
learning_rate = 1e-4
keep_prob_rate = 0.7 #
max_epoch = 3
BATCH_SIZE = 50

DOWNLOAD_MNIST = False
if not(os.path.exists('./mnist/')) or not os.listdir('./mnist/'):
    # not mnist dir or mnist is empyt dir
    DOWNLOAD_MNIST = True


train_data = torchvision.datasets.MNIST(root='./mnist/',train=True, transform=torchvision.transforms.ToTensor(), download=DOWNLOAD_MNIST,)
train_loader = Data.DataLoader(dataset = train_data ,batch_size= BATCH_SIZE ,shuffle= True)

test_data = torchvision.datasets.MNIST(root = './mnist/',train = False)
test_x = Variable(torch.unsqueeze(test_data.test_data,dim  = 1),volatile = True).type(torch.FloatTensor)[:500]/255.
test_y = test_data.test_labels[:500].numpy()

class CNN(nn.Module):
    def __init__(self):
        super(CNN, self).__init__()
        self.conv1 = nn.Sequential(
            nn.Conv2d( # ???
                # patch 7 * 7 ; 1  in channels ; 32 out channels ; ; stride is 1
                # padding style is same(that means the convolution opration's input and output have the same size)
                in_channels=      1,  
                out_channels=    32,
                kernel_size=      7,
                stride=           1,
                padding=          3,
            ),
            nn.ReLU(),        # activation function
            nn.MaxPool2d(2),  # pooling operation
        )
        self.conv2 = nn.Sequential( # ???
            # line 1 : convolution function, patch 5*5 , 32 in channels ;64 out channels; padding style is same; stride is 1
            # line 2 : choosing your activation funciont
            # line 3 : pooling operation function.
            nn.Conv2d(
                in_channels=32, 
                out_channels=64, 
                kernel_size=5, 
                stride=1, 
                padding=2,
            ),
            nn.ReLU(),
            nn.MaxPool2d(2),
        )
        self.out1 = nn.Linear( 7*7*64 , 1024 , bias= True)   # full connection layer one

        self.dropout = nn.Dropout(keep_prob_rate)
        self.out2 = nn.Linear(1024,10,bias=True)



    def forward(self, x):
        x = self.conv1(x)
        x = self.conv2(x)
        x = x.view(x.size(0), -1)  # flatten the output of coonv2 to (batch_size ,64 * 7 * 7)    # ???
        out1 = self.out1(x)
        out1 = F.relu(out1)
        out1 = self.dropout(out1)
        out2 = self.out2(out1)
        output = F.softmax(out2)
        return output


def test(cnn):
    global prediction
    y_pre = cnn(test_x)
    _,pre_index= torch.max(y_pre,1)
    pre_index= pre_index.view(-1)
    prediction = pre_index.data.numpy()
    correct  = np.sum(prediction == test_y)
    return correct / 500.0


def train(cnn):
    optimizer = torch.optim.Adam(cnn.parameters(), lr=learning_rate )
    loss_func = nn.CrossEntropyLoss()
    for epoch in range(max_epoch):
        for step, (x_, y_) in enumerate(train_loader):
            x ,y= Variable(x_),Variable(y_)
            output = cnn(x)  
            loss = loss_func(output,y)
            optimizer.zero_grad()
            loss.backward()
            optimizer.step()
            
            if step != 0 and step % 20 ==0:
                print("=" * 10,step,"="*5,"="*5, "test accuracy is ",test(cnn) ,"=" * 10 )

if __name__ == '__main__':
    cnn = CNN()
    train(cnn)
# Out:
# Downloading http://yann.lecun.com/exdb/mnist/train-images-idx3-ubyte.gz
# Downloading http://202.120.161.162/cache/5/02/yann.lecun.com/34152be34c1115808d82493371362afe/train-images-idx3-ubyte.gz to ./mnist/MNIST\raw\train-images-idx3-ubyte.gz
# 100%|██████████| 9912422/9912422 [00:00<00:00, 10976650.76it/s]
# Extracting ./mnist/MNIST\raw\train-images-idx3-ubyte.gz to ./mnist/MNIST\raw
#
# Downloading http://yann.lecun.com/exdb/mnist/train-labels-idx1-ubyte.gz
# Downloading http://202.120.161.162/cache/11/02/yann.lecun.com/32a667c2f3de678798ae039d04726fa1/train-labels-idx1-ubyte.gz to ./mnist/MNIST\raw\train-labels-idx1-ubyte.gz
# 100%|██████████| 28881/28881 [00:00<00:00, 9627697.81it/s]
# Extracting ./mnist/MNIST\raw\train-labels-idx1-ubyte.gz to ./mnist/MNIST\raw
#
# Downloading http://yann.lecun.com/exdb/mnist/t10k-images-idx3-ubyte.gz
# Downloading http://202.120.161.162/cache/1/02/yann.lecun.com/b80c4efc17eabb28908f865775412435/t10k-images-idx3-ubyte.gz to ./mnist/MNIST\raw\t10k-images-idx3-ubyte.gz
# 100%|██████████| 1648877/1648877 [00:00<00:00, 9356078.23it/s]
# Extracting ./mnist/MNIST\raw\t10k-images-idx3-ubyte.gz to ./mnist/MNIST\raw
#
# Downloading http://yann.lecun.com/exdb/mnist/t10k-labels-idx1-ubyte.gz
# Downloading http://yann.lecun.com/exdb/mnist/t10k-labels-idx1-ubyte.gz to ./mnist/MNIST\raw\t10k-labels-idx1-ubyte.gz
# 100%|██████████| 4542/4542 [00:00<?, ?it/s]
# d:\py3.10\lib\site-packages\torchvision\datasets\mnist.py:80: UserWarning: test_data has been renamed data
#   warnings.warn("test_data has been renamed data")
# C:\Users\fallen lord　OMEN\AppData\Local\Temp\ipykernel_24120\4069808873.py:24: UserWarning: volatile was removed and now has no effect. Use `with torch.no_grad():` instead.
#   test_x = Variable(torch.unsqueeze(test_data.test_data,dim  = 1),volatile = True).type(torch.FloatTensor)[:500]/255.
# d:\py3.10\lib\site-packages\torchvision\datasets\mnist.py:70: UserWarning: test_labels has been renamed targets
#   warnings.warn("test_labels has been renamed targets")
# C:\Users\fallen lord　OMEN\AppData\Local\Temp\ipykernel_24120\4069808873.py:72: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   output = F.softmax(out2)
# Extracting ./mnist/MNIST\raw\t10k-labels-idx1-ubyte.gz to ./mnist/MNIST\raw
#
# ========== 20 ===== ===== test accuracy is  0.226 ==========
# ========== 40 ===== ===== test accuracy is  0.346 ==========
# ========== 60 ===== ===== test accuracy is  0.45 ==========
# ========== 80 ===== ===== test accuracy is  0.532 ==========
# ========== 100 ===== ===== test accuracy is  0.614 ==========
# ========== 120 ===== ===== test accuracy is  0.696 ==========
# ========== 140 ===== ===== test accuracy is  0.7 ==========
# ========== 160 ===== ===== test accuracy is  0.722 ==========
# ========== 180 ===== ===== test accuracy is  0.788 ==========
# ========== 200 ===== ===== test accuracy is  0.776 ==========
# ========== 220 ===== ===== test accuracy is  0.822 ==========
# ========== 240 ===== ===== test accuracy is  0.806 ==========
# ========== 260 ===== ===== test accuracy is  0.844 ==========
# ========== 280 ===== ===== test accuracy is  0.862 ==========
# ========== 300 ===== ===== test accuracy is  0.872 ==========
# ========== 320 ===== ===== test accuracy is  0.872 ==========
# ========== 340 ===== ===== test accuracy is  0.86 ==========
# ========== 360 ===== ===== test accuracy is  0.85 ==========
# ========== 380 ===== ===== test accuracy is  0.878 ==========
# ========== 400 ===== ===== test accuracy is  0.894 ==========
# ========== 420 ===== ===== test accuracy is  0.896 ==========
# ========== 440 ===== ===== test accuracy is  0.91 ==========
# ========== 460 ===== ===== test accuracy is  0.896 ==========
# ========== 480 ===== ===== test accuracy is  0.892 ==========
# ========== 500 ===== ===== test accuracy is  0.888 ==========
# ========== 520 ===== ===== test accuracy is  0.908 ==========
# ========== 540 ===== ===== test accuracy is  0.9 ==========
# ========== 560 ===== ===== test accuracy is  0.896 ==========
# ========== 580 ===== ===== test accuracy is  0.906 ==========
# ========== 600 ===== ===== test accuracy is  0.924 ==========
# ========== 620 ===== ===== test accuracy is  0.912 ==========
# ========== 640 ===== ===== test accuracy is  0.92 ==========
# ========== 660 ===== ===== test accuracy is  0.916 ==========
# ========== 680 ===== ===== test accuracy is  0.914 ==========
# ========== 700 ===== ===== test accuracy is  0.924 ==========
# ========== 720 ===== ===== test accuracy is  0.912 ==========
# ========== 740 ===== ===== test accuracy is  0.922 ==========
# ========== 760 ===== ===== test accuracy is  0.928 ==========
# ========== 780 ===== ===== test accuracy is  0.934 ==========
# ========== 800 ===== ===== test accuracy is  0.932 ==========
# ========== 820 ===== ===== test accuracy is  0.93 ==========
# ========== 840 ===== ===== test accuracy is  0.928 ==========
# ========== 860 ===== ===== test accuracy is  0.938 ==========
# ========== 880 ===== ===== test accuracy is  0.934 ==========
# ========== 900 ===== ===== test accuracy is  0.932 ==========
# ========== 920 ===== ===== test accuracy is  0.928 ==========
# ========== 940 ===== ===== test accuracy is  0.948 ==========
# ========== 960 ===== ===== test accuracy is  0.934 ==========
# ========== 980 ===== ===== test accuracy is  0.922 ==========
# ========== 1000 ===== ===== test accuracy is  0.946 ==========
# ========== 1020 ===== ===== test accuracy is  0.93 ==========
# ========== 1040 ===== ===== test accuracy is  0.946 ==========
# ========== 1060 ===== ===== test accuracy is  0.946 ==========
# ========== 1080 ===== ===== test accuracy is  0.942 ==========
# ========== 1100 ===== ===== test accuracy is  0.934 ==========
# ========== 1120 ===== ===== test accuracy is  0.934 ==========
# ========== 1140 ===== ===== test accuracy is  0.944 ==========
# ========== 1160 ===== ===== test accuracy is  0.944 ==========
# ========== 1180 ===== ===== test accuracy is  0.944 ==========
# ========== 20 ===== ===== test accuracy is  0.964 ==========
# ========== 40 ===== ===== test accuracy is  0.96 ==========
# ========== 60 ===== ===== test accuracy is  0.95 ==========
# ========== 80 ===== ===== test accuracy is  0.948 ==========
# ========== 100 ===== ===== test accuracy is  0.942 ==========
# ========== 120 ===== ===== test accuracy is  0.948 ==========
# ========== 140 ===== ===== test accuracy is  0.952 ==========
# ========== 160 ===== ===== test accuracy is  0.958 ==========
# ========== 180 ===== ===== test accuracy is  0.956 ==========
# ========== 200 ===== ===== test accuracy is  0.96 ==========
# ========== 220 ===== ===== test accuracy is  0.956 ==========
# ========== 240 ===== ===== test accuracy is  0.948 ==========
# ========== 260 ===== ===== test accuracy is  0.966 ==========
# ========== 280 ===== ===== test accuracy is  0.958 ==========
# ========== 300 ===== ===== test accuracy is  0.946 ==========
# ========== 320 ===== ===== test accuracy is  0.958 ==========
# ========== 340 ===== ===== test accuracy is  0.94 ==========
# ========== 360 ===== ===== test accuracy is  0.958 ==========
# ========== 380 ===== ===== test accuracy is  0.962 ==========
# ========== 400 ===== ===== test accuracy is  0.954 ==========
# ========== 420 ===== ===== test accuracy is  0.96 ==========
# ========== 440 ===== ===== test accuracy is  0.958 ==========
# ========== 460 ===== ===== test accuracy is  0.954 ==========
# ========== 480 ===== ===== test accuracy is  0.956 ==========
# ========== 500 ===== ===== test accuracy is  0.96 ==========
# ========== 520 ===== ===== test accuracy is  0.962 ==========
# ========== 540 ===== ===== test accuracy is  0.952 ==========
# ========== 560 ===== ===== test accuracy is  0.964 ==========
# ========== 580 ===== ===== test accuracy is  0.956 ==========
# ========== 600 ===== ===== test accuracy is  0.958 ==========
# ========== 620 ===== ===== test accuracy is  0.966 ==========
# ========== 640 ===== ===== test accuracy is  0.964 ==========
# ========== 660 ===== ===== test accuracy is  0.962 ==========
# ========== 680 ===== ===== test accuracy is  0.954 ==========
# ========== 700 ===== ===== test accuracy is  0.966 ==========
# ========== 720 ===== ===== test accuracy is  0.96 ==========
# ========== 740 ===== ===== test accuracy is  0.964 ==========
# ========== 760 ===== ===== test accuracy is  0.958 ==========
# ========== 780 ===== ===== test accuracy is  0.964 ==========
# ========== 800 ===== ===== test accuracy is  0.968 ==========
# ========== 820 ===== ===== test accuracy is  0.958 ==========
# ========== 840 ===== ===== test accuracy is  0.964 ==========
# ========== 860 ===== ===== test accuracy is  0.962 ==========
# ========== 880 ===== ===== test accuracy is  0.966 ==========
# ========== 900 ===== ===== test accuracy is  0.964 ==========
# ========== 920 ===== ===== test accuracy is  0.97 ==========
# ========== 940 ===== ===== test accuracy is  0.96 ==========
# ========== 960 ===== ===== test accuracy is  0.962 ==========
# ========== 980 ===== ===== test accuracy is  0.964 ==========
# ========== 1000 ===== ===== test accuracy is  0.96 ==========
# ========== 1020 ===== ===== test accuracy is  0.966 ==========
# ========== 1040 ===== ===== test accuracy is  0.956 ==========
# ========== 1060 ===== ===== test accuracy is  0.974 ==========
# ========== 1080 ===== ===== test accuracy is  0.972 ==========
# ========== 1100 ===== ===== test accuracy is  0.958 ==========
# ========== 1120 ===== ===== test accuracy is  0.972 ==========
# ========== 1140 ===== ===== test accuracy is  0.972 ==========
# ========== 1160 ===== ===== test accuracy is  0.974 ==========
# ========== 1180 ===== ===== test accuracy is  0.974 ==========
# ========== 20 ===== ===== test accuracy is  0.968 ==========
# ========== 40 ===== ===== test accuracy is  0.966 ==========
# ========== 60 ===== ===== test accuracy is  0.968 ==========
# ========== 80 ===== ===== test accuracy is  0.974 ==========
# ========== 100 ===== ===== test accuracy is  0.966 ==========
# ========== 120 ===== ===== test accuracy is  0.966 ==========
# ========== 140 ===== ===== test accuracy is  0.968 ==========
# ========== 160 ===== ===== test accuracy is  0.976 ==========
# ========== 180 ===== ===== test accuracy is  0.962 ==========
# ========== 200 ===== ===== test accuracy is  0.97 ==========
# ========== 220 ===== ===== test accuracy is  0.968 ==========
# ========== 240 ===== ===== test accuracy is  0.966 ==========
# ========== 260 ===== ===== test accuracy is  0.966 ==========
# ========== 280 ===== ===== test accuracy is  0.96 ==========
# ========== 300 ===== ===== test accuracy is  0.97 ==========
# ========== 320 ===== ===== test accuracy is  0.972 ==========
# ========== 340 ===== ===== test accuracy is  0.976 ==========
# ========== 360 ===== ===== test accuracy is  0.976 ==========
# ========== 380 ===== ===== test accuracy is  0.98 ==========
# ========== 400 ===== ===== test accuracy is  0.972 ==========
# ========== 420 ===== ===== test accuracy is  0.974 ==========
# ========== 440 ===== ===== test accuracy is  0.978 ==========
# ========== 460 ===== ===== test accuracy is  0.974 ==========
# ========== 480 ===== ===== test accuracy is  0.958 ==========
# ========== 500 ===== ===== test accuracy is  0.972 ==========
# ========== 520 ===== ===== test accuracy is  0.974 ==========
# ========== 540 ===== ===== test accuracy is  0.97 ==========
# ========== 560 ===== ===== test accuracy is  0.978 ==========
# ========== 580 ===== ===== test accuracy is  0.978 ==========
# ========== 600 ===== ===== test accuracy is  0.98 ==========
# ========== 620 ===== ===== test accuracy is  0.98 ==========
# ========== 640 ===== ===== test accuracy is  0.97 ==========
# ========== 660 ===== ===== test accuracy is  0.976 ==========
# ========== 680 ===== ===== test accuracy is  0.966 ==========
# ========== 700 ===== ===== test accuracy is  0.972 ==========
# ========== 720 ===== ===== test accuracy is  0.964 ==========
# ========== 740 ===== ===== test accuracy is  0.97 ==========
# ========== 760 ===== ===== test accuracy is  0.978 ==========
# ========== 780 ===== ===== test accuracy is  0.978 ==========
# ========== 800 ===== ===== test accuracy is  0.98 ==========
# ========== 820 ===== ===== test accuracy is  0.972 ==========
# ========== 840 ===== ===== test accuracy is  0.976 ==========
# ========== 860 ===== ===== test accuracy is  0.962 ==========
# ========== 880 ===== ===== test accuracy is  0.978 ==========
# ========== 900 ===== ===== test accuracy is  0.972 ==========
# ========== 920 ===== ===== test accuracy is  0.978 ==========
# ========== 940 ===== ===== test accuracy is  0.972 ==========
# ========== 960 ===== ===== test accuracy is  0.97 ==========
# ========== 980 ===== ===== test accuracy is  0.972 ==========
# ========== 1000 ===== ===== test accuracy is  0.974 ==========
# ========== 1020 ===== ===== test accuracy is  0.97 ==========
# ========== 1040 ===== ===== test accuracy is  0.972 ==========
# ========== 1060 ===== ===== test accuracy is  0.974 ==========
# ========== 1080 ===== ===== test accuracy is  0.978 ==========
# ========== 1100 ===== ===== test accuracy is  0.968 ==========
# ========== 1120 ===== ===== test accuracy is  0.978 ==========
# ========== 1140 ===== ===== test accuracy is  0.978 ==========
# ========== 1160 ===== ===== test accuracy is  0.97 ==========
# ========== 1180 ===== ===== test accuracy is  0.98 ==========
